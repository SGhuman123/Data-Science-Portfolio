# %% [markdown]
# <a href="https://colab.research.google.com/github/SGhuman123/Data-Science-Portfolio/blob/main/Udemy_Master_Time_Series_Analysis/Using_Facebook_Prophet_to_forecast_demand_for_shelter_in_New_York/Prophet_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Challenge: Demand for Shelter
#
# Predicting the future is always difficult. In this interesting case study, we use Prophet to predict the Demand for Shelter in New York City. As well, we will learn about Cross-validation and Parameter Tuning in Time Series
#
# 1. **Prepare Dataframe**
#   * Facebook Prophet has a lot of quirks.
# The Date variable must be called ds and
# the time-series has to be y. Additionally,
# the date must be in the format yyyymm-dd. Finally, don't forget to prepare
# the events like was shown in the
# practice tutorial.
#
# 2. **Training and test set**
#   * In Time-Series, the training and test
# set follows a different structure, given
# that information without context does
# not have value. Additionally, the test
# set should have the same number of
# days as a real-life forecast.
#
# 3. **Prophet Model and Accuracy assessment**
#   * Build the Facebook Prophet model,
# while adding the regressors. Next,
# build the future data frame to
# perform the forecast. In the end,
# assess the accuracy of the model.
#
# 4. **Visualization**
#   * Facebook Prophet has very cool built-in
# visualization functions. Use them! As a
# visual learner myself, I like to see
# pretty graphs to know what the model
# tells me.
#
# 5. **Parameter Tuning**
#   * Do the Parameter Tuning while
# performing cross-validation. Tune
# the parameters we tuned in the
# practice tutorial. Good luck!

# %% [markdown]
# # Libraries and data

# %%
# !pip freeze
# Out:
# absl-py==1.4.0
# accelerate==1.1.1
# aiohappyeyeballs==2.4.3
# aiohttp==3.11.2
# aiosignal==1.3.1
# alabaster==1.0.0
# albucore==0.0.19
# albumentations==1.4.20
# altair==4.2.2
# annotated-types==0.7.0
# anyio==3.7.1
# argon2-cffi==23.1.0
# argon2-cffi-bindings==21.2.0
# array_record==0.5.1
# arviz==0.20.0
# astropy==6.1.6
# astropy-iers-data==0.2024.11.18.0.35.2
# astunparse==1.6.3
# async-timeout==4.0.3
# atpublic==4.1.0
# attrs==24.2.0
# audioread==3.0.1
# autograd==1.7.0
# babel==2.16.0
# backcall==0.2.0
# beautifulsoup4==4.12.3
# bigframes==1.27.0
# bigquery-magics==0.4.0
# bleach==6.2.0
# blinker==1.9.0
# blis==0.7.11
# blosc2==2.7.1
# bokeh==3.6.1
# Bottleneck==1.4.2
# bqplot==0.12.43
# branca==0.8.0
# CacheControl==0.14.1
# cachetools==5.5.0
# catalogue==2.0.10
# certifi==2024.8.30
# cffi==1.17.1
# chardet==5.2.0
# charset-normalizer==3.4.0
# chex==0.1.87
# clarabel==0.9.0
# click==8.1.7
# cloudpathlib==0.20.0
# cloudpickle==3.1.0
# cmake==3.30.5
# cmdstanpy==1.2.4
# colorcet==3.1.0
# colorlover==0.3.0
# colour==0.1.5
# community==1.0.0b1
# confection==0.1.5
# cons==0.4.6
# contourpy==1.3.1
# cryptography==43.0.3
# cuda-python==12.2.1
# cudf-cu12 @ https://pypi.nvidia.com/cudf-cu12/cudf_cu12-24.10.1-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl
# cufflinks==0.17.3
# cupy-cuda12x==12.2.0
# cvxopt==1.3.2
# cvxpy==1.5.4
# cycler==0.12.1
# cymem==2.0.8
# Cython==3.0.11
# dask==2024.10.0
# datascience==0.17.6
# db-dtypes==1.3.1
# dbus-python==1.2.18
# debugpy==1.8.0
# decorator==4.4.2
# defusedxml==0.7.1
# Deprecated==1.2.15
# diffusers==0.31.0
# distro==1.9.0
# dlib==19.24.2
# dm-tree==0.1.8
# docker-pycreds==0.4.0
# docstring_parser==0.16
# docutils==0.21.2
# dopamine_rl==4.0.9
# duckdb==1.1.3
# earthengine-api==1.2.0
# easydict==1.13
# ecos==2.0.14
# editdistance==0.8.1
# eerepr==0.0.4
# einops==0.8.0
# en-core-web-sm @ https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl#sha256=86cc141f63942d4b2c5fcee06630fd6f904788d2f0ab005cce45aadb8fb73889
# entrypoints==0.4
# et_xmlfile==2.0.0
# etils==1.10.0
# etuples==0.3.9
# eval_type_backport==0.2.0
# exceptiongroup==1.2.2
# fastai==2.7.18
# fastcore==1.7.20
# fastdownload==0.0.7
# fastjsonschema==2.20.0
# fastprogress==1.0.3
# fastrlock==0.8.2
# filelock==3.16.1
# firebase-admin==6.5.0
# Flask==3.0.3
# flatbuffers==24.3.25
# flax==0.8.5
# folium==0.18.0
# fonttools==4.55.0
# frozendict==2.4.6
# frozenlist==1.5.0
# fsspec==2024.10.0
# future==1.0.0
# gast==0.6.0
# gcsfs==2024.10.0
# GDAL==3.6.4
# gdown==5.2.0
# geemap==0.35.1
# gensim==4.3.3
# geocoder==1.38.1
# geographiclib==2.0
# geopandas==1.0.1
# geopy==2.4.1
# gin-config==0.5.0
# gitdb==4.0.11
# GitPython==3.1.43
# glob2==0.7
# google==2.0.3
# google-ai-generativelanguage==0.6.10
# google-api-core==2.19.2
# google-api-python-client==2.151.0
# google-auth==2.27.0
# google-auth-httplib2==0.2.0
# google-auth-oauthlib==1.2.1
# google-cloud-aiplatform==1.71.1
# google-cloud-bigquery==3.25.0
# google-cloud-bigquery-connection==1.16.1
# google-cloud-bigquery-storage==2.27.0
# google-cloud-bigtable==2.27.0
# google-cloud-core==2.4.1
# google-cloud-datastore==2.20.1
# google-cloud-firestore==2.19.0
# google-cloud-functions==1.18.1
# google-cloud-iam==2.16.1
# google-cloud-language==2.15.1
# google-cloud-pubsub==2.27.1
# google-cloud-resource-manager==1.13.1
# google-cloud-storage==2.8.0
# google-cloud-translate==3.17.0
# google-colab @ file:///colabtools/dist/google_colab-1.0.0.tar.gz
# google-crc32c==1.6.0
# google-generativeai==0.8.3
# google-pasta==0.2.0
# google-resumable-media==2.7.2
# googleapis-common-protos==1.66.0
# googledrivedownloader==0.4
# graphviz==0.20.3
# greenlet==3.1.1
# grpc-google-iam-v1==0.13.1
# grpcio==1.68.0
# grpcio-status==1.62.3
# gspread==6.0.2
# gspread-dataframe==3.3.1
# gym==0.25.2
# gym-notices==0.0.8
# h11==0.14.0
# h5netcdf==1.4.1
# h5py==3.12.1
# holidays==0.61
# holoviews==1.20.0
# html5lib==1.1
# httpcore==1.0.7
# httpimport==1.4.0
# httplib2==0.22.0
# httpx==0.27.2
# huggingface-hub==0.26.2
# humanize==4.11.0
# hyperopt==0.2.7
# ibis-framework==9.2.0
# idna==3.10
# imageio==2.36.0
# imageio-ffmpeg==0.5.1
# imagesize==1.4.1
# imbalanced-learn==0.12.4
# imgaug==0.4.0
# immutabledict==4.2.1
# importlib_metadata==8.5.0
# importlib_resources==6.4.5
# imutils==0.5.4
# inflect==7.4.0
# iniconfig==2.0.0
# intel-cmplr-lib-ur==2025.0.0
# intel-openmp==2025.0.0
# ipyevents==2.0.2
# ipyfilechooser==0.6.0
# ipykernel==5.5.6
# ipyleaflet==0.19.2
# ipyparallel==8.8.0
# ipython==7.34.0
# ipython-genutils==0.2.0
# ipython-sql==0.5.0
# ipytree==0.2.2
# ipywidgets==7.7.1
# itsdangerous==2.2.0
# jax==0.4.33
# jax-cuda12-pjrt==0.4.33
# jax-cuda12-plugin==0.4.33
# jaxlib==0.4.33
# jeepney==0.7.1
# jellyfish==1.1.0
# jieba==0.42.1
# Jinja2==3.1.4
# jiter==0.7.1
# joblib==1.4.2
# jsonpatch==1.33
# jsonpickle==4.0.0
# jsonpointer==3.0.0
# jsonschema==4.23.0
# jsonschema-specifications==2024.10.1
# jupyter-client==6.1.12
# jupyter-console==6.1.0
# jupyter-leaflet==0.19.2
# jupyter-server==1.24.0
# jupyter_core==5.7.2
# jupyterlab_pygments==0.3.0
# jupyterlab_widgets==3.0.13
# kaggle==1.6.17
# kagglehub==0.3.4
# keras==3.5.0
# keyring==23.5.0
# kiwisolver==1.4.7
# langchain==0.3.7
# langchain-core==0.3.19
# langchain-text-splitters==0.3.2
# langcodes==3.4.1
# langsmith==0.1.143
# language_data==1.2.0
# launchpadlib==1.10.16
# lazr.restfulclient==0.14.4
# lazr.uri==1.0.6
# lazy_loader==0.4
# libclang==18.1.1
# libcudf-cu12 @ https://pypi.nvidia.com/libcudf-cu12/libcudf_cu12-24.10.1-py3-none-manylinux_2_28_x86_64.whl
# librosa==0.10.2.post1
# lightgbm==4.5.0
# linkify-it-py==2.0.3
# llvmlite==0.43.0
# locket==1.0.0
# logical-unification==0.4.6
# lxml==5.3.0
# marisa-trie==1.2.1
# Markdown==3.7
# markdown-it-py==3.0.0
# MarkupSafe==3.0.2
# matplotlib==3.8.0
# matplotlib-inline==0.1.7
# matplotlib-venn==1.1.1
# mdit-py-plugins==0.4.2
# mdurl==0.1.2
# miniKanren==1.0.3
# missingno==0.5.2
# mistune==3.0.2
# mizani==0.13.0
# mkl==2025.0.0
# ml-dtypes==0.4.1
# mlxtend==0.23.3
# more-itertools==10.5.0
# moviepy==1.0.3
# mpmath==1.3.0
# msgpack==1.1.0
# multidict==6.1.0
# multipledispatch==1.0.0
# multitasking==0.0.11
# murmurhash==1.0.10
# music21==9.3.0
# namex==0.0.8
# natsort==8.4.0
# nbclassic==1.1.0
# nbclient==0.10.0
# nbconvert==7.16.4
# nbformat==5.10.4
# ndindex==1.9.2
# nest-asyncio==1.6.0
# networkx==3.4.2
# nibabel==5.3.2
# nltk==3.9.1
# notebook==6.5.5
# notebook_shim==0.2.4
# numba==0.60.0
# numexpr==2.10.1
# numpy==1.26.4
# nvidia-cublas-cu12==12.6.3.3
# nvidia-cuda-cupti-cu12==12.6.80
# nvidia-cuda-nvcc-cu12==12.6.77
# nvidia-cuda-runtime-cu12==12.6.77
# nvidia-cudnn-cu12==9.5.1.17
# nvidia-cufft-cu12==11.3.0.4
# nvidia-curand-cu12==10.3.7.77
# nvidia-cusolver-cu12==11.7.1.2
# nvidia-cusparse-cu12==12.5.4.2
# nvidia-nccl-cu12==2.23.4
# nvidia-nvjitlink-cu12==12.6.77
# nvtx==0.2.10
# nx-cugraph-cu12 @ https://pypi.nvidia.com/nx-cugraph-cu12/nx_cugraph_cu12-24.10.0-py3-none-any.whl
# oauth2client==4.1.3
# oauthlib==3.2.2
# openai==1.54.4
# opencv-contrib-python==4.10.0.84
# opencv-python==4.10.0.84
# opencv-python-headless==4.10.0.84
# openpyxl==3.1.5
# opentelemetry-api==1.28.2
# opentelemetry-sdk==1.28.2
# opentelemetry-semantic-conventions==0.49b2
# opt_einsum==3.4.0
# optax==0.2.4
# optree==0.13.1
# orbax-checkpoint==0.6.4
# orjson==3.10.11
# osqp==0.6.7.post3
# packaging==24.2
# pandas==2.2.2
# pandas-datareader==0.10.0
# pandas-gbq==0.24.0
# pandas-stubs==2.2.2.240909
# pandocfilters==1.5.1
# panel==1.5.4
# param==2.1.1
# parso==0.8.4
# parsy==2.1
# partd==1.4.2
# pathlib==1.0.1
# patsy==1.0.1
# peewee==3.17.8
# peft==0.13.2
# pexpect==4.9.0
# pickleshare==0.7.5
# pillow==11.0.0
# platformdirs==4.3.6
# plotly==5.24.1
# plotnine==0.14.1
# pluggy==1.5.0
# polars==1.9.0
# pooch==1.8.2
# portpicker==1.5.2
# preshed==3.0.9
# prettytable==3.12.0
# proglog==0.1.10
# progressbar2==4.5.0
# prometheus_client==0.21.0
# promise==2.3
# prompt_toolkit==3.0.48
# propcache==0.2.0
# prophet==1.1.6
# proto-plus==1.25.0
# protobuf==4.25.5
# psutil==5.9.5
# psycopg2==2.9.10
# ptyprocess==0.7.0
# py-cpuinfo==9.0.0
# py4j==0.10.9.7
# pyarrow==17.0.0
# pyarrow-hotfix==0.6
# pyasn1==0.6.1
# pyasn1_modules==0.4.1
# pycocotools==2.0.8
# pycparser==2.22
# pydantic==2.9.2
# pydantic_core==2.23.4
# pydata-google-auth==1.8.2
# pydot==3.0.2
# pydotplus==2.0.2
# PyDrive==1.3.1
# PyDrive2==1.21.1
# pyerfa==2.0.1.5
# pygame==2.6.1
# pygit2==1.16.0
# Pygments==2.18.0
# PyGObject==3.42.1
# PyJWT==2.10.0
# pylibcudf-cu12 @ https://pypi.nvidia.com/pylibcudf-cu12/pylibcudf_cu12-24.10.1-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl
# pylibcugraph-cu12==24.10.0
# pylibraft-cu12==24.10.0
# pymc==5.18.2
# pymystem3==0.2.0
# pynvjitlink-cu12==0.4.0
# pyogrio==0.10.0
# PyOpenGL==3.1.7
# pyOpenSSL==24.2.1
# pyparsing==3.2.0
# pyperclip==1.9.0
# pyproj==3.7.0
# pyshp==2.3.1
# PySocks==1.7.1
# pyspark==3.5.3
# pytensor==2.26.3
# pytest==8.3.3
# python-apt==0.0.0
# python-box==7.2.0
# python-dateutil==2.8.2
# python-louvain==0.16
# python-slugify==8.0.4
# python-utils==3.9.0
# pytz==2024.2
# pyviz_comms==3.0.3
# PyYAML==6.0.2
# pyzmq==24.0.1
# qdldl==0.1.7.post4
# ratelim==0.1.6
# referencing==0.35.1
# regex==2024.9.11
# requests==2.32.3
# requests-oauthlib==1.3.1
# requests-toolbelt==1.0.0
# requirements-parser==0.9.0
# rich==13.9.4
# rmm-cu12==24.10.0
# rpds-py==0.21.0
# rpy2==3.4.2
# rsa==4.9
# safetensors==0.4.5
# scikit-image==0.24.0
# scikit-learn==1.5.2
# scipy==1.13.1
# scooby==0.10.0
# scs==3.2.7
# seaborn==0.13.2
# SecretStorage==3.3.1
# Send2Trash==1.8.3
# sentence-transformers==3.2.1
# sentencepiece==0.2.0
# sentry-sdk==2.18.0
# setproctitle==1.3.4
# shap==0.46.0
# shapely==2.0.6
# shellingham==1.5.4
# simple-parsing==0.1.6
# six==1.16.0
# sklearn-pandas==2.2.0
# slicer==0.0.8
# smart-open==7.0.5
# smmap==5.0.1
# sniffio==1.3.1
# snowballstemmer==2.2.0
# soundfile==0.12.1
# soupsieve==2.6
# soxr==0.5.0.post1
# spacy==3.7.5
# spacy-legacy==3.0.12
# spacy-loggers==1.0.5
# Sphinx==8.1.3
# sphinxcontrib-applehelp==2.0.0
# sphinxcontrib-devhelp==2.0.0
# sphinxcontrib-htmlhelp==2.1.0
# sphinxcontrib-jsmath==1.0.1
# sphinxcontrib-qthelp==2.0.0
# sphinxcontrib-serializinghtml==2.0.0
# SQLAlchemy==2.0.36
# sqlglot==25.1.0
# sqlparse==0.5.2
# srsly==2.4.8
# stanio==0.5.1
# statsmodels==0.14.4
# StrEnum==0.4.15
# stringzilla==3.10.10
# sympy==1.13.1
# tables==3.10.1
# tabulate==0.9.0
# tbb==2022.0.0
# tcmlib==1.2.0
# tenacity==9.0.0
# tensorboard==2.17.1
# tensorboard-data-server==0.7.2
# tensorflow==2.17.1
# tensorflow-datasets==4.9.7
# tensorflow-hub==0.16.1
# tensorflow-io-gcs-filesystem==0.37.1
# tensorflow-metadata==1.13.1
# tensorflow-probability==0.24.0
# tensorstore==0.1.68
# termcolor==2.5.0
# terminado==0.18.1
# text-unidecode==1.3
# textblob==0.17.1
# tf-slim==1.1.0
# tf_keras==2.17.0
# thinc==8.2.5
# threadpoolctl==3.5.0
# tifffile==2024.9.20
# timm==1.0.11
# tinycss2==1.4.0
# tokenizers==0.20.3
# toml==0.10.2
# tomli==2.1.0
# toolz==0.12.1
# torch @ https://download.pytorch.org/whl/cu121_full/torch-2.5.1%2Bcu121-cp310-cp310-linux_x86_64.whl
# torchaudio @ https://download.pytorch.org/whl/cu121/torchaudio-2.5.1%2Bcu121-cp310-cp310-linux_x86_64.whl
# torchsummary==1.5.1
# torchvision @ https://download.pytorch.org/whl/cu121/torchvision-0.20.1%2Bcu121-cp310-cp310-linux_x86_64.whl
# tornado==6.3.3
# tqdm==4.66.6
# traitlets==5.7.1
# traittypes==0.2.1
# transformers==4.46.2
# tweepy==4.14.0
# typeguard==4.4.1
# typer==0.13.0
# types-pytz==2024.2.0.20241003
# types-setuptools==75.6.0.20241126
# typing_extensions==4.12.2
# tzdata==2024.2
# tzlocal==5.2
# uc-micro-py==1.0.3
# umf==0.9.0
# uritemplate==4.1.1
# urllib3==2.2.3
# vega-datasets==0.9.0
# wadllib==1.3.6
# wandb==0.18.7
# wasabi==1.1.3
# wcwidth==0.2.13
# weasel==0.4.1
# webcolors==24.11.1
# webencodings==0.5.1
# websocket-client==1.8.0
# Werkzeug==3.1.3
# widgetsnbextension==3.6.10
# wordcloud==1.9.4
# wrapt==1.16.0
# xarray==2024.10.0
# xarray-einstats==0.8.0
# xgboost==2.1.2
# xlrd==2.0.1
# xyzservices==2024.9.0
# yarl==1.17.2
# yellowbrick==1.5
# yfinance==0.2.49
# zipp==3.21.0

# %%
# Mount Drive to access files
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Path to the folder
# %cd /content/drive/MyDrive/Udemy Time Series Forecasting/Modern Time Series Forecasting Techniques /CAPSTONE PROJECT_ Prophet
# Out:
# /content/drive/MyDrive/Udemy Time Series Forecasting/Modern Time Series Forecasting Techniques /CAPSTONE PROJECT_ Prophet

# %%
# Import libraries
import pandas as pd
from prophet import Prophet
from prophet.plot import plot_plotly, plot_components_plotly
from prophet.diagnostics import cross_validation, performance_metrics

# %% [markdown]
# 1. **Prepare Dataframe**
#   * Facebook Prophet has a lot of quirks.
# The Date variable must be called ds and
# the time-series has to be y. Additionally,
# the date must be in the format yyyymm-dd. Finally, don't forget to prepare
# the events like was shown in the
# practice tutorial.

# %%
# Load the CSV file
df = pd.read_csv('DHS_weekly.csv')
# Rename the columns, date to 'ds' and target variable to 'y'
df.rename(columns={'Date': 'ds', 'Total Individuals in Shelter': 'y'}, inplace=True)
# convert the column 'date' to datetime
df['ds'] = pd.to_datetime(df['ds'])
df.tail()
# Out:
#             ds       y  Easter  Thanksgiving  Christmas  Temperature
# 361 2020-12-06  375444       0             0          0    10.072857
# 362 2020-12-13  375820       0             0          0     8.208571
# 363 2020-12-20  375615       0             0          0     3.535714
# 364 2020-12-27  374203       0             0          1     7.510000
# 365 2021-01-03  212514       0             0          0     6.625000

# %%
# Prepare holiday dataframe for Easter
holidays = pd.DataFrame({
    'holiday': 'Easter',  # Name of the holiday
    'ds': df['ds'][df['Easter'] == 1],  # Dates of the holiday
    'lower_window': 0,  # Number of days before the holiday to include in the effect
    'upper_window': 1,  # Number of days after the holiday to include in the effect
})

# Loop through other holidays (Thanksgiving and Christmas) to append them to the holidays dataframe
for holiday in ['Thanksgiving', 'Christmas']:
    temp = pd.DataFrame({
        'holiday': holiday,  # Name of the holiday
        'ds': df['ds'][df[holiday] == 1],  # Dates of the holiday
        'lower_window': 0,  # Number of days before the holiday to include in the effect
        'upper_window': 1,  # Number of days after the holiday to include in the effect
    })
    holidays = pd.concat([holidays, temp])  # Concatenate the new holiday dataframe to the existing holidays dataframe

holidays
# Out:
#           holiday         ds  lower_window  upper_window
# 15         Easter 2014-04-20             0             1
# 65         Easter 2015-04-05             0             1
# 116        Easter 2016-03-27             0             1
# 171        Easter 2017-04-16             0             1
# 221        Easter 2018-04-01             0             1
# 276        Easter 2019-04-21             0             1
# 327        Easter 2020-04-12             0             1
# 47   Thanksgiving 2014-11-30             0             1
# 99   Thanksgiving 2015-11-29             0             1
# 151  Thanksgiving 2016-11-27             0             1
# 203  Thanksgiving 2017-11-26             0             1
# 255  Thanksgiving 2018-11-25             0             1
# 308  Thanksgiving 2019-12-01             0             1
# 360  Thanksgiving 2020-11-29             0             1
# 51      Christmas 2014-12-28             0             1
# 103     Christmas 2015-12-27             0             1
# 155     Christmas 2016-12-25             0             1
# 208     Christmas 2017-12-31             0             1
# 260     Christmas 2018-12-30             0             1
# 312     Christmas 2019-12-29             0             1
# 364     Christmas 2020-12-27             0             1

# %% [markdown]
# # Prophet Model
#
# 2. **Training and test set**
#   * In Time-Series, the training and test
# set follows a different structure, given
# that information without context does
# not have value. Additionally, the test
# set should have the same number of
# days as a real-life forecast.

# %%
# Assuming the test set is intended to be for the last 60 days in the dataset
max_date = df['ds'].max()  # Get the maximum date in the dataset
split_date = max_date - pd.Timedelta(weeks=13)  # Set the split date 13 weeks (91 days) before the last date

# Split the data into training and testing sets based on the split date
train_df = df[df['ds'] <= split_date]  # Training set includes data up to and including the split date
test_df = df[df['ds'] > split_date]  # Testing set includes data after the split date

# %% [markdown]
# 3. **Prophet Model and Accuracy assessment**
#   * Build the Facebook Prophet model,
# while adding the regressors. Next,
# build the future data frame to
# perform the forecast. In the end,
# assess the accuracy of the model.

# %%
# Initialize the Prophet model
model = Prophet(holidays=holidays) # Add the holidays
model.add_regressor('Temperature')  # Adding temperature as a regressor
# Fit the model on the training data
model.fit(train_df)
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/sprxqecz.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/x4xzk1tt.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=42380', 'data', 'file=/tmp/tmp89kiof8r/sprxqecz.json', 'init=/tmp/tmp89kiof8r/x4xzk1tt.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modelq3ax_ike/prophet_model-20241204051532.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:15:32 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:15:32 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
# Create a dataframe for predictions
future_df = model.make_future_dataframe(periods=13, freq='W')  # Generate future dates for 13 weeks

# Include the regressors in the future dataframe
future_df = future_df.merge(df[['ds', 'Temperature']], on='ds', how='left')

# Predict over the future dataframe
forecast = model.predict(future_df)

# %%
# Evaluate predictions

# Aligning predicted 'yhat' with the actual 'y' in the test set
test_df = test_df.set_index('ds')  # Set the index of test_df to 'ds' (date)
forecast.set_index('ds', inplace=True)  # Set the index of forecast to 'ds' (date)
forecast = forecast.join(test_df['y'])  # Join the actual 'y' values from the test set to the forecast dataframe

# Calculate mean absolute error
forecast['error'] = (forecast['y'] - forecast['yhat']).abs()  # Calculate the absolute error between actual and predicted values
mae = forecast['error'].mean()  # Calculate the mean of the absolute errors
print(f"Mean Absolute Error: {mae}")  # Print the Mean Absolute Error
# Out:
# Mean Absolute Error: 29485.304917293375

# %% [markdown]
# 4. **Visualization**
#   * Facebook Prophet has very cool built-in
# visualization functions. Use them! As a
# visual learner myself, I like to see
# pretty graphs to know what the model
# tells me.

# %%
# Visualizing the forecast
from prophet.plot import plot_plotly
plot_plotly(model, forecast.reset_index())
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ad2b612c-ed0f-4088-908d-d21cfee90988" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ad2b612c-ed0f-4088-908d-d21cfee90988")) {                    Plotly.newPlot(                        "ad2b612c-ed0f-4088-908d-d21cfee90988",                        [{"marker":{"color":"black","size":4},"mode":"markers","name":"Actual","x":["2014-01-05T00:00:00","2014-01-12T00:00:00","2014-01-19T00:00:00","2014-01-26T00:00:00","2014-02-02T00:00:00","2014-02-09T00:00:00","2014-02-16T00:00:00","2014-02-23T00:00:00","2014-03-02T00:00:00","2014-03-09T00:00:00","2014-03-16T00:00:00","2014-03-23T00:00:00","2014-03-30T00:00:00","2014-04-06T00:00:00","2014-04-13T00:00:00","2014-04-20T00:00:00","2014-04-27T00:00:00","2014-05-04T00:00:00","2014-05-11T00:00:00","2014-05-18T00:00:00","2014-05-25T00:00:00","2014-06-01T00:00:00","2014-06-08T00:00:00","2014-06-15T00:00:00","2014-06-22T00:00:00","2014-06-29T00:00:00","2014-07-06T00:00:00","2014-07-13T00:00:00","2014-07-20T00:00:00","2014-07-27T00:00:00","2014-08-03T00:00:00","2014-08-10T00:00:00","2014-08-17T00:00:00","2014-08-24T00:00:00","2014-08-31T00:00:00","2014-09-07T00:00:00","2014-09-14T00:00:00","2014-09-21T00:00:00","2014-09-28T00:00:00","2014-10-05T00:00:00","2014-10-12T00:00:00","2014-10-19T00:00:00","2014-10-26T00:00:00","2014-11-02T00:00:00","2014-11-09T00:00:00","2014-11-16T00:00:00","2014-11-23T00:00:00","2014-11-30T00:00:00","2014-12-07T00:00:00","2014-12-14T00:00:00","2014-12-21T00:00:00","2014-12-28T00:00:00","2015-01-04T00:00:00","2015-01-11T00:00:00","2015-01-18T00:00:00","2015-01-25T00:00:00","2015-02-01T00:00:00","2015-02-08T00:00:00","2015-02-15T00:00:00","2015-02-22T00:00:00","2015-03-01T00:00:00","2015-03-08T00:00:00","2015-03-15T00:00:00","2015-03-22T00:00:00","2015-03-29T00:00:00","2015-04-05T00:00:00","2015-04-12T00:00:00","2015-04-19T00:00:00","2015-04-26T00:00:00","2015-05-03T00:00:00","2015-05-10T00:00:00","2015-05-17T00:00:00","2015-05-24T00:00:00","2015-05-31T00:00:00","2015-06-07T00:00:00","2015-06-14T00:00:00","2015-06-21T00:00:00","2015-06-28T00:00:00","2015-07-05T00:00:00","2015-07-12T00:00:00","2015-07-19T00:00:00","2015-07-26T00:00:00","2015-08-02T00:00:00","2015-08-09T00:00:00","2015-08-16T00:00:00","2015-08-23T00:00:00","2015-08-30T00:00:00","2015-09-06T00:00:00","2015-09-13T00:00:00","2015-09-20T00:00:00","2015-09-27T00:00:00","2015-10-04T00:00:00","2015-10-11T00:00:00","2015-10-18T00:00:00","2015-10-25T00:00:00","2015-11-01T00:00:00","2015-11-08T00:00:00","2015-11-15T00:00:00","2015-11-22T00:00:00","2015-11-29T00:00:00","2015-12-06T00:00:00","2015-12-13T00:00:00","2015-12-20T00:00:00","2015-12-27T00:00:00","2016-01-03T00:00:00","2016-01-10T00:00:00","2016-01-17T00:00:00","2016-01-24T00:00:00","2016-01-31T00:00:00","2016-02-07T00:00:00","2016-02-14T00:00:00","2016-02-21T00:00:00","2016-02-28T00:00:00","2016-03-06T00:00:00","2016-03-13T00:00:00","2016-03-20T00:00:00","2016-03-27T00:00:00","2016-04-03T00:00:00","2016-04-10T00:00:00","2016-04-17T00:00:00","2016-04-24T00:00:00","2016-05-01T00:00:00","2016-05-08T00:00:00","2016-05-15T00:00:00","2016-05-22T00:00:00","2016-05-29T00:00:00","2016-06-05T00:00:00","2016-06-12T00:00:00","2016-06-19T00:00:00","2016-06-26T00:00:00","2016-07-03T00:00:00","2016-07-10T00:00:00","2016-07-17T00:00:00","2016-07-24T00:00:00","2016-07-31T00:00:00","2016-08-07T00:00:00","2016-08-14T00:00:00","2016-08-21T00:00:00","2016-08-28T00:00:00","2016-09-04T00:00:00","2016-09-11T00:00:00","2016-09-18T00:00:00","2016-09-25T00:00:00","2016-10-02T00:00:00","2016-10-09T00:00:00","2016-10-16T00:00:00","2016-10-23T00:00:00","2016-10-30T00:00:00","2016-11-06T00:00:00","2016-11-13T00:00:00","2016-11-20T00:00:00","2016-11-27T00:00:00","2016-12-04T00:0 ...

# %%
from prophet.plot import plot_plotly, plot_components_plotly
import matplotlib.pyplot as plt

# Plot the components of the forecast
fig_components = plot_components_plotly(model, forecast.reset_index())
fig_components.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/plotly/io/_json.py:560: UserWarning:
#
# Discarding nonzero nanoseconds in conversion.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="8326bf37-f9c5-4e1d-a63b-2ce93a620aff" class="plotly-graph-div" style="height:800px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8326bf37-f9c5-4e1d-a63b-2ce93a620aff")) {                    Plotly.newPlot(                        "8326bf37-f9c5-4e1d-a63b-2ce93a620aff",                        [{"line":{"color":"#0072B2","width":2},"mode":"lines","name":"trend","x":["2014-01-05T00:00:00","2014-01-12T00:00:00","2014-01-19T00:00:00","2014-01-26T00:00:00","2014-02-02T00:00:00","2014-02-09T00:00:00","2014-02-16T00:00:00","2014-02-23T00:00:00","2014-03-02T00:00:00","2014-03-09T00:00:00","2014-03-16T00:00:00","2014-03-23T00:00:00","2014-03-30T00:00:00","2014-04-06T00:00:00","2014-04-13T00:00:00","2014-04-20T00:00:00","2014-04-27T00:00:00","2014-05-04T00:00:00","2014-05-11T00:00:00","2014-05-18T00:00:00","2014-05-25T00:00:00","2014-06-01T00:00:00","2014-06-08T00:00:00","2014-06-15T00:00:00","2014-06-22T00:00:00","2014-06-29T00:00:00","2014-07-06T00:00:00","2014-07-13T00:00:00","2014-07-20T00:00:00","2014-07-27T00:00:00","2014-08-03T00:00:00","2014-08-10T00:00:00","2014-08-17T00:00:00","2014-08-24T00:00:00","2014-08-31T00:00:00","2014-09-07T00:00:00","2014-09-14T00:00:00","2014-09-21T00:00:00","2014-09-28T00:00:00","2014-10-05T00:00:00","2014-10-12T00:00:00","2014-10-19T00:00:00","2014-10-26T00:00:00","2014-11-02T00:00:00","2014-11-09T00:00:00","2014-11-16T00:00:00","2014-11-23T00:00:00","2014-11-30T00:00:00","2014-12-07T00:00:00","2014-12-14T00:00:00","2014-12-21T00:00:00","2014-12-28T00:00:00","2015-01-04T00:00:00","2015-01-11T00:00:00","2015-01-18T00:00:00","2015-01-25T00:00:00","2015-02-01T00:00:00","2015-02-08T00:00:00","2015-02-15T00:00:00","2015-02-22T00:00:00","2015-03-01T00:00:00","2015-03-08T00:00:00","2015-03-15T00:00:00","2015-03-22T00:00:00","2015-03-29T00:00:00","2015-04-05T00:00:00","2015-04-12T00:00:00","2015-04-19T00:00:00","2015-04-26T00:00:00","2015-05-03T00:00:00","2015-05-10T00:00:00","2015-05-17T00:00:00","2015-05-24T00:00:00","2015-05-31T00:00:00","2015-06-07T00:00:00","2015-06-14T00:00:00","2015-06-21T00:00:00","2015-06-28T00:00:00","2015-07-05T00:00:00","2015-07-12T00:00:00","2015-07-19T00:00:00","2015-07-26T00:00:00","2015-08-02T00:00:00","2015-08-09T00:00:00","2015-08-16T00:00:00","2015-08-23T00:00:00","2015-08-30T00:00:00","2015-09-06T00:00:00","2015-09-13T00:00:00","2015-09-20T00:00:00","2015-09-27T00:00:00","2015-10-04T00:00:00","2015-10-11T00:00:00","2015-10-18T00:00:00","2015-10-25T00:00:00","2015-11-01T00:00:00","2015-11-08T00:00:00","2015-11-15T00:00:00","2015-11-22T00:00:00","2015-11-29T00:00:00","2015-12-06T00:00:00","2015-12-13T00:00:00","2015-12-20T00:00:00","2015-12-27T00:00:00","2016-01-03T00:00:00","2016-01-10T00:00:00","2016-01-17T00:00:00","2016-01-24T00:00:00","2016-01-31T00:00:00","2016-02-07T00:00:00","2016-02-14T00:00:00","2016-02-21T00:00:00","2016-02-28T00:00:00","2016-03-06T00:00:00","2016-03-13T00:00:00","2016-03-20T00:00:00","2016-03-27T00:00:00","2016-04-03T00:00:00","2016-04-10T00:00:00","2016-04-17T00:00:00","2016-04-24T00:00:00","2016-05-01T00:00:00","2016-05-08T00:00:00","2016-05-15T00:00:00","2016-05-22T00:00:00","2016-05-29T00:00:00","2016-06-05T00:00:00","2016-06-12T00:00:00","2016-06-19T00:00:00","2016-06-26T00:00:00","2016-07-03T00:00:00","2016-07-10T00:00:00","2016-07-17T00:00:00","2016-07-24T00:00:00","2016-07-31T00:00:00","2016-08-07T00:00:00","2016-08-14T00:00:00","2016-08-21T00:00:00","2016-08-28T00:00:00","2016-09-04T00:00:00","2016-09-11T00:00:00","2016-09-18T00:00:00","2016-09-25T00:00:00","2016-10-02T00:00:00","2016-10-09T00:00:00","2016-10-16T00:00:00","2016-10-23T00:00:00","2016-10-30T00:00:00","2016-11-06T00:00:00","2016-11-13T00:00:00","2016-11-20T00:00:00","2016-11-27T00:00:00","2016-12-04T00:00: ...

# %% [markdown]
# # Parameter Tuning
#
# 5. **Parameter Tuning**
#   * Do the Parameter Tuning while
# performing cross-validation. Tune
# the parameters we tuned in the
# practice tutorial. Good luck!

# %%
from prophet.diagnostics import cross_validation, performance_metrics
import itertools
import numpy as np

# %%
# Define all combinations of parameters for grid search
param_grid = {
    'changepoint_prior_scale': [0.01, 0.1, 0.5],
    'seasonality_prior_scale': [0.1, 1.0, 10.0],
    'holidays_prior_scale': [0.1, 1.0, 10.0],
    'seasonality_mode': ['additive', 'multiplicative']
}

# Generate all combinations of parameters
all_params = [dict(zip(param_grid.keys(), v)) for v in itertools.product(*param_grid.values())]
rmses = []  # Store the RMSEs for each params here

# %%
# Iterate over all parameter combinations
for params in all_params:
    # Initialize and fit the Prophet model with the given parameters and holidays
    m = Prophet(holidays=holidays, **params).fit(train_df)

    # Perform cross-validation
    df_cv = cross_validation(
        m,
        initial='1500 days',  # Initial training period
        period='42 days',     # Period between cutoff dates
        horizon='91 days',    # Forecast horizon
        parallel="processes"  # Use parallel processing
    )

    # Calculate performance metrics
    df_p = performance_metrics(df_cv, rolling_window=1)

    # Append the first RMSE value to the rmses list
    rmses.append(df_p['rmse'].values[0])
# Out:
# Streaming output truncated to the last 5000 lines.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/2neh8e43.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/8sxdpad3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/lpc8vhml.json
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=8456', 'data', 'file=/tmp/tmp89kiof8r/qv18u8hk.json', 'init=/tmp/tmp89kiof8r/8sxdpad3.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_model6uwjl3ch/prophet_model-20241204051950.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:19:50 - cmdstanpy - INFO - Chain [1] start processing
# DEBUG:cmdstanpy:idx 0
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=35767', 'data', 'file=/tmp/tmp89kiof8r/2neh8e43.json', 'init=/tmp/tmp89kiof8r/lpc8vhml.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_model3dtf6jak/prophet_model-20241204051950.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:19:50 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:19:50 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/32kaa7u1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/_mkrexej.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=84318', 'data', 'file=/tmp/tmp89kiof8r/32kaa7u1.json', 'init=/tmp/tmp89kiof8r/_mkrexej.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modelxxjx2yu1/prophet_model-20241204051951.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:19:51 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:19:51 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/996rvl0x.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/2qdtvv_e.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=89336', 'data', 'file=/tmp/tmp89kiof8r/996rvl0x.json', 'init=/tmp/tmp89kiof8r/2qdtvv_e.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_model7ya_fji1/prophet_model-20241204051951.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:19:51 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:19:51 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/naztb29f.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/n9pde1kp.json
# 05:19:51 - cmdstanpy - INFO - Chain [1] done processing
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=4905', 'data', 'file=/tmp/tmp89kiof8r/naztb29f.json', 'init=/tmp/tmp89kiof8r/n9pde1kp.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modelxrnaesp2/prophet_model-20241204051951.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# INFO:cmdstanpy:Chain [1] done processing
# 05:19:51 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/wg4tfpdx.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/c3juryhv.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=92771', 'data', 'file=/tmp/tmp89kiof8r/wg4tfpdx.json', 'init=/tmp/tmp89kiof8r/c3juryhv.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modela8qnjbpi/prophet_model-20241204051952.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:19:52 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:19:52 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/bd7mpxld.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/iakif9lw.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=16112', 'data', 'file=/tmp/tmp89kiof8r/bd7mpxld.json', 'init=/tmp/tmp89kiof8r/iakif9lw.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_model6zj2p7a3/prophet_model-20241204051952.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:19:52 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:19:52 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/r4os6hdt.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/_kigjc6t.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=64198', 'data', 'file=/tmp/tmp89kiof8r/r4os6hdt.json', 'init=/tmp/tmp89kiof8r/_kigjc6t.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_model9ezuhoxa/prophet_model-20241204051953.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:19:53 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:19:53 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/ybxwo51n.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/y7dbr4qk.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=68470', 'data', 'file=/tmp/tmp89kiof8r/ybxwo51n.json', 'init=/tmp/tmp89kiof8r/y7dbr4qk.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_model195xxt00/prophet_model-20241204051953.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:19:53 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:19:53 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 05:19:53 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/iebo9z86.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/t2_nq311.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=52386', 'data', 'file=/tmp/tmp89kiof8r/iebo9z86.json', 'init=/tmp/tmp89kiof8r/t2_nq311.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modelkn87hc3o/prophet_model-20241204051953.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:19:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/3m6i1n5s.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/7t5ysrq7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=91610', 'data', 'file=/tmp/tmp89kiof8r/3m6i1n5s.json', 'init=/tmp/tmp89kiof8r/7t5ysrq7.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modelo3vfk1kx/prophet_model-20241204051954.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:19:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:19:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 05:19:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/me04vqf9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/gqgjjuxx.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/7edymfqo.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=570', 'data', 'file=/tmp/tmp89kiof8r/me04vqf9.json', 'init=/tmp/tmp89kiof8r/7edymfqo.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_model6ujmcq8m/prophet_model-20241204051954.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:19:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/519z3m2e.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=29446', 'data', 'file=/tmp/tmp89kiof8r/gqgjjuxx.json', 'init=/tmp/tmp89kiof8r/519z3m2e.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_model_ux_khf4/prophet_model-20241204051954.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:19:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:19:55 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/jq6o910x.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/vhhhcy11.json
# 05:19:55 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=69034', 'data', 'file=/tmp/tmp89kiof8r/jq6o910x.json', 'init=/tmp/tmp89kiof8r/vhhhcy11.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_model7mgdice3/prophet_model-20241204051955.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:19:55 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/sroaxxds.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/auvba3f4.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=28971', 'data', 'file=/tmp/tmp89kiof8r/sroaxxds.json', 'init=/tmp/tmp89kiof8r/auvba3f4.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modelguhk9g6v/prophet_model-20241204051955.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:19:55 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:19:55 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 05:19:56 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/4_p8n2ur.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/k35o8g8t.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=96108', 'data', 'file=/tmp/tmp89kiof8r/4_p8n2ur.json', 'init=/tmp/tmp89kiof8r/k35o8g8t.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modelf_sgj71i/prophet_model-20241204051956.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:19:56 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/8j0ziohm.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/ahfqnb92.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=59039', 'data', 'file=/tmp/tmp89kiof8r/8j0ziohm.json', 'init=/tmp/tmp89kiof8r/ahfqnb92.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modelfkw4p723/prophet_model-20241204051956.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:19:56 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:19:56 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 05:19:57 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/t7xi_u07.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/8zu_0j4i.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=99159', 'data', 'file=/tmp/tmp89kiof8r/t7xi_u07.json', 'init=/tmp/tmp89kiof8r/8zu_0j4i.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modelwi_4lh5m/prophet_model-20241204051957.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:19:57 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:19:58 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Making 21 forecasts with cutoffs between 2018-03-18 00:00:00 and 2020-07-05 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7c97736b5780>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/xrp2jc30.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/9v8ky3a7.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/_a42s727.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/he88whof.json
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=80001', 'data', 'file=/tmp/tmp89kiof8r/xrp2jc30.json', 'init=/tmp/tmp89kiof8r/_a42s727.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modely22f6esu/prophet_model-20241204051958.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:19:58 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=32946', 'data', 'file=/tmp/tmp89kiof8r/9v8ky3a7.json', 'init=/tmp/tmp89kiof8r/he88whof.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modelkk5y0cml/prophet_model-20241204051958.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:19:58 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:19:58 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 05:19:59 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/x2q3_sgx.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/cag_ld02.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/r5l9t17t.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=59546', 'data', 'file=/tmp/tmp89kiof8r/x2q3_sgx.json', 'init=/tmp/tmp89kiof8r/r5l9t17t.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modelvi7l44kr/prophet_model-20241204051959.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:19:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/ys1aqubw.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=1469', 'data', 'file=/tmp/tmp89kiof8r/cag_ld02.json', 'init=/tmp/tmp89kiof8r/ys1aqubw.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modelnwnh9m1m/prophet_model-20241204051959.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:19:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:19:59 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 05:20:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/yngkj_ca.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/0rp6uokt.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=70501', 'data', 'file=/tmp/tmp89kiof8r/yngkj_ca.json', 'init=/tmp/tmp89kiof8r/0rp6uokt.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modelo366toco/prophet_model-20241204052000.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:20:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/nqkuyyr6.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/xmbqkj1k.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=15211', 'data', 'file=/tmp/tmp89kiof8r/nqkuyyr6.json', 'init=/tmp/tmp89kiof8r/xmbqkj1k.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modelcjsy_qua/prophet_model-20241204052000.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:20:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:20:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 05:20:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/0a8mzf64.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/8dx692ji.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/j6l1g8q5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=23700', 'data', 'file=/tmp/tmp89kiof8r/0a8mzf64.json', 'init=/tmp/tmp89kiof8r/j6l1g8q5.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_model15ereagj/prophet_model-20241204052001.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:20:01 - cmdstanpy - INFO - Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/rcp774xq.json
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=437', 'data', 'file=/tmp/tmp89kiof8r/8dx692ji.json', 'init=/tmp/tmp89kiof8r/rcp774xq.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_model8215emoo/prophet_model-20241204052001.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:20:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:20:01 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 05:20:01 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/827hkvu1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/5ql0bfmm.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=82424', 'data', 'file=/tmp/tmp89kiof8r/827hkvu1.json', 'init=/tmp/tmp89kiof8r/5ql0bfmm.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_model9phjqa_p/prophet_model-20241204052002.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/m_w0f76j.json
# 05:20:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/issfhsx0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=81814', 'data', 'file=/tmp/tmp89kiof8r/m_w0f76j.json', 'init=/tmp/tmp89kiof8r/issfhsx0.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modelcz0tu5fl/prophet_model-20241204052002.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:20:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:20:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 05:20:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/h94vy7tc.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/z8ia8rt1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=26622', 'data', 'file=/tmp/tmp89kiof8r/h94vy7tc.json', 'init=/tmp/tmp89kiof8r/z8ia8rt1.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modellc0s0iol/prophet_model-20241204052003.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:20:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/v3n_dz11.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/v8987z0i.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=25477', 'data', 'file=/tmp/tmp89kiof8r/v3n_dz11.json', 'init=/tmp/tmp89kiof8r/v8987z0i.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modelu6u1ebho/prophet_model-20241204052003.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:20:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:20:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/xahg82u3.json
# 05:20:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/nx6pfh9z.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=91796', 'data', 'file=/tmp/tmp89kiof8r/xahg82u3.json', 'init=/tmp/tmp89kiof8r/nx6pfh9z.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modelk22d7ykx/prophet_model-20241204052004.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:20:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/kyk5hyqg.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/dvcofs5w.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=85526', 'data', 'file=/tmp/tmp89kiof8r/kyk5hyqg.json', 'init=/tmp/tmp89kiof8r/dvcofs5w.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modelp2owi1_s/prophet_model-20241204052004.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:20:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:20:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/6wzw34up.json
# 05:20:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/1pq3zvdj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=98595', 'data', 'file=/tmp/tmp89kiof8r/6wzw34up.json', 'init=/tmp/tmp89kiof8r/1pq3zvdj.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modelymduxdv5/prophet_model-20241204052005.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:20:05 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/hscx4max.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/r57tuoew.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=18621', 'data', 'file=/tmp/tmp89kiof8r/hscx4max.json', 'init=/tmp/tmp89kiof8r/r57tuoew.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modelkmluz0rp/prophet_model-20241204052005.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:20:05 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:20:06 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/f448rsc9.json
# 05:20:06 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/smo62kk5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=14296', 'data', 'file=/tmp/tmp89kiof8r/f448rsc9.json', 'init=/tmp/tmp89kiof8r/smo62kk5.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modelj5w_jfb5/prophet_model-20241204052006.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:20:06 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/fd8i9gta.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/v38_394p.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=1171', 'data', 'file=/tmp/tmp89kiof8r/fd8i9gta.json', 'init=/tmp/tmp89kiof8r/v38_394p.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modelktb68tts/prophet_model-20241204052006.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:20:07 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:20:07 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/im8iz8sn.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/xlgaums6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=12304', 'data', 'file=/tmp/tmp89kiof8r/im8iz8sn.json', 'init=/tmp/tmp89kiof8r/xlgaums6.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modelgirll7jc/prophet_model-20241204052007.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:20:07 - cmdstanpy - INFO - Chain [1] start processing
# 05:20:07 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/mrdv0j5d.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/ubfrdkj_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=54454', 'data', 'file=/tmp/tmp89kiof8r/mrdv0j5d.json', 'init=/tmp/tmp89kiof8r/ubfrdkj_.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_model_1mqkc5k/prophet_model-20241204052007.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:20:07 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:20:08 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 05:20:08 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/iumm1aed.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/iyc2_ars.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=7365', 'data', 'file=/tmp/tmp89kiof8r/iumm1aed.json', 'init=/tmp/tmp89kiof8r/iyc2_ars.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_model8azacm3b/prophet_model-20241204052008.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:20:08 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:20:09 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/9bfm76o5.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/7zbe3xss.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=72810', 'data', 'file=/tmp/tmp89kiof8r/9bfm76o5.json', 'init=/tmp/tmp89kiof8r/7zbe3xss.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modelv1ng9lwz/prophet_model-20241204052009.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:20:09 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:20:10 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Making 21 forecasts with cutoffs between 2018-03-18 00:00:00 and 2020-07-05 00:00:00
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7c976af1ce50>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/2q8ofo17.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/e051a2nw.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/ts5lm8od.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=43275', 'data', 'file=/tmp/tmp89kiof8r/2q8ofo17.json', 'init=/tmp/tmp89kiof8r/ts5lm8od.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modelxwqyw05c/prophet_model-20241204052010.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:20:10 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/zx4vbxvq.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=78910', 'data', 'file=/tmp/tmp89kiof8r/e051a2nw.json', 'init=/tmp/tmp89kiof8r/zx4vbxvq.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_model3s9bafhq/prophet_model-20241204052010.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:20:10 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:20:10 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 05:20:11 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/zk2gedr6.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/7_380fd_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=48111', 'data', 'file=/tmp/tmp89kiof8r/zk2gedr6.json', 'init=/tmp/tmp89kiof8r/7_380fd_.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modelv66filvp/prophet_model-20241204052011.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:20:11 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/fvl77mfn.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/t_l2ienz.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=98895', 'data', 'file=/tmp/tmp89kiof8r/fvl77mfn.json', 'init=/tmp/tmp89kiof8r/t_l2ienz.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modelfigd5641/prophet_model-20241204052011.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:20:11 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:20:11 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/_gzzv8u4.json
# 05:20:12 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/fo_b7_6d.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=95642', 'data', 'file=/tmp/tmp89kiof8r/_gzzv8u4.json', 'init=/tmp/tmp89kiof8r/fo_b7_6d.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modelq4gczbkr/prophet_model-20241204052012.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:20:12 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/bjelk_w7.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/ez51qoq8.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=87354', 'data', 'file=/tmp/tmp89kiof8r/bjelk_w7.json', 'init=/tmp/tmp89kiof8r/ez51qoq8.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modeli__amqeo/prophet_model-20241204052012.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:20:12 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:20:12 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/4isotivf.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/tdltpefk.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=31155', 'data', 'file=/tmp/tmp89kiof8r/4isotivf.json', 'init=/tmp/tmp89kiof8r/tdltpefk.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modelwuxy1l1m/prophet_model-20241204052013.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:20:13 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:20:13 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/5gi24urq.json
# 05:20:13 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/6k07j6gv.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=18987', 'data', 'file=/tmp/tmp89kiof8r/5gi24urq.json', 'init=/tmp/tmp89kiof8r/6k07j6gv.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_model_kffpgoe/prophet_model-20241204052013.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:20:13 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/9i5ckwzt.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/r_8p3b81.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=67964', 'data', 'file=/tmp/tmp89kiof8r/9i5ckwzt.json', 'init=/tmp/tmp89kiof8r/r_8p3b81.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modelgelaz3n0/prophet_model-20241204052013.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:20:13 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:20:13 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/9oq8kksm.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/hbt72pe3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=60243', 'data', 'file=/tmp/tmp89kiof8r/9oq8kksm.json', 'init=/tmp/tmp89kiof8r/hbt72pe3.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_model75xsybu1/prophet_model-20241204052014.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:20:14 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 05:20:14 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/atzek1bo.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/z6ckxjk6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=56884', 'data', 'file=/tmp/tmp89kiof8r/atzek1bo.json', 'init=/tmp/tmp89kiof8r/z6ckxjk6.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modelebv2aafq/prophet_model-20241204052014.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:20:14 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:20:14 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/d9ix3od9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/6idc9d6e.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=83768', 'data', 'file=/tmp/tmp89kiof8r/d9ix3od9.json', 'init=/tmp/tmp89kiof8r/6idc9d6e.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modeln83qmtq2/prophet_model-20241204052014.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:20:14 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:20:14 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/r3r0nkov.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/0bp5ni8n.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=33069', 'data', 'file=/tmp/tmp89kiof8r/r3r0nkov.json', 'init=/tmp/tmp89kiof8r/0bp5ni8n.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modelzl01zg67/prophet_model-20241204052015.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:20:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:20:15 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/w9jh7bh9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/i1j8bay9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=99517', 'data', 'file=/tmp/tmp89kiof8r/w9jh7bh9.json', 'init=/tmp/tmp89kiof8r/i1j8bay9.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modelaqmjiqh4/prophet_model-20241204052015.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:20:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:20:16 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 05:20:16 - cmdstanpy - INFO - Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/u3pjulo9.json
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/v8c2dahj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=66637', 'data', 'file=/tmp/tmp89kiof8r/u3pjulo9.json', 'init=/tmp/tmp89kiof8r/v8c2dahj.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modelpw27q4i3/prophet_model-20241204052016.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:20:16 - cmdstanpy - INFO - Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/ftfkocuf.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/zr4wt7j0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=18559', 'data', 'file=/tmp/tmp89kiof8r/ftfkocuf.json', 'init=/tmp/tmp89kiof8r/zr4wt7j0.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modelk2uvhzn4/prophet_model-20241204052016.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:20:16 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:20:16 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/86nvxyip.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/n2d14fdr.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=99703', 'data', 'file=/tmp/tmp89kiof8r/86nvxyip.json', 'init=/tmp/tmp89kiof8r/n2d14fdr.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_model_l_w9f50/prophet_model-20241204052017.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:20:17 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:20:17 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/nyi_r8hf.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/bu5aers5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=13340', 'data', 'file=/tmp/tmp89kiof8r/nyi_r8hf.json', 'init=/tmp/tmp89kiof8r/bu5aers5.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modeld2drd3g5/prophet_model-20241204052017.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:20:17 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:20:17 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 05:20:17 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/0ftrngx6.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/ht30yxt0.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/p0y_t8ww.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=77389', 'data', 'file=/tmp/tmp89kiof8r/0ftrngx6.json', 'init=/tmp/tmp89kiof8r/p0y_t8ww.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modelh_wiie2v/prophet_model-20241204052018.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:20:18 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/0p72_95t.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=9751', 'data', 'file=/tmp/tmp89kiof8r/ht30yxt0.json', 'init=/tmp/tmp89kiof8r/0p72_95t.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_model5jvgl2h1/prophet_model-20241204052018.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:20:18 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:20:18 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 05:20:18 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/6p0oc3fx.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/1p2dit5e.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=91530', 'data', 'file=/tmp/tmp89kiof8r/6p0oc3fx.json', 'init=/tmp/tmp89kiof8r/1p2dit5e.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modelcf_bpqqs/prophet_model-20241204052018.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:20:18 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:20:19 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/ofmxdmof.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/_dnty2nx.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=44401', 'data', 'file=/tmp/tmp89kiof8r/ofmxdmof.json', 'init=/tmp/tmp89kiof8r/_dnty2nx.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modelspgjaw3q/prophet_model-20241204052019.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:20:19 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:20:19 - cmdstanpy - INFO - Chain [1] done processing
# ...
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/41ecwv9g.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/2sm4eysl.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/bwzshgpz.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/qbgs10sw.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=21717', 'data', 'file=/tmp/tmp89kiof8r/2sm4eysl.json', 'init=/tmp/tmp89kiof8r/qbgs10sw.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modelmd_7pc29/prophet_model-20241204052402.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=56907', 'data', 'file=/tmp/tmp89kiof8r/41ecwv9g.json', 'init=/tmp/tmp89kiof8r/bwzshgpz.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_model2bu23zvh/prophet_model-20241204052402.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:24:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:24:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:24:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 05:24:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/tlm5un73.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/0vpu612n.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=1617', 'data', 'file=/tmp/tmp89kiof8r/tlm5un73.json', 'init=/tmp/tmp89kiof8r/0vpu612n.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modelnt78teuv/prophet_model-20241204052403.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:24:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/s1cctrx_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/02t4knwg.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=7641', 'data', 'file=/tmp/tmp89kiof8r/s1cctrx_.json', 'init=/tmp/tmp89kiof8r/02t4knwg.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modeloujaajy1/prophet_model-20241204052404.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:24:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:24:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 05:24:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/mw7ydfrx.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/_zhq6pjb.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=86421', 'data', 'file=/tmp/tmp89kiof8r/mw7ydfrx.json', 'init=/tmp/tmp89kiof8r/_zhq6pjb.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modelmffauz50/prophet_model-20241204052404.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:24:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/o2uex2a0.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/26qr6fco.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=42134', 'data', 'file=/tmp/tmp89kiof8r/o2uex2a0.json', 'init=/tmp/tmp89kiof8r/26qr6fco.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_model0mnfsoei/prophet_model-20241204052405.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:24:05 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:24:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 05:24:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/ipnlbbdf.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/ml3rt9ie.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=98748', 'data', 'file=/tmp/tmp89kiof8r/ipnlbbdf.json', 'init=/tmp/tmp89kiof8r/ml3rt9ie.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modelhn1podwp/prophet_model-20241204052405.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:24:05 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/n6rr8kmo.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/z4z7ppv3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=48817', 'data', 'file=/tmp/tmp89kiof8r/n6rr8kmo.json', 'init=/tmp/tmp89kiof8r/z4z7ppv3.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_model7qohhkgc/prophet_model-20241204052406.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:24:06 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:24:06 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 05:24:06 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/ngv29n40.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/jaib5zeb.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/zi2ysf50.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=30192', 'data', 'file=/tmp/tmp89kiof8r/ngv29n40.json', 'init=/tmp/tmp89kiof8r/zi2ysf50.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modelm0h_2btu/prophet_model-20241204052407.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:24:07 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/2nxwpt8e.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=99320', 'data', 'file=/tmp/tmp89kiof8r/jaib5zeb.json', 'init=/tmp/tmp89kiof8r/2nxwpt8e.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modeltwkhovhl/prophet_model-20241204052407.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:24:07 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:24:07 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 05:24:07 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/l44vfjta.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/fwayzr4s.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/0ds3_w2t.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/i6aa02g5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=28493', 'data', 'file=/tmp/tmp89kiof8r/l44vfjta.json', 'init=/tmp/tmp89kiof8r/0ds3_w2t.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_model9617b21a/prophet_model-20241204052408.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# 05:24:08 - cmdstanpy - INFO - Chain [1] start processing
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=57543', 'data', 'file=/tmp/tmp89kiof8r/fwayzr4s.json', 'init=/tmp/tmp89kiof8r/i6aa02g5.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modelzq8vxr3u/prophet_model-20241204052408.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:24:08 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:24:09 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 05:24:09 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/dcqbfbrk.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/q0r5njjy.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=29759', 'data', 'file=/tmp/tmp89kiof8r/dcqbfbrk.json', 'init=/tmp/tmp89kiof8r/q0r5njjy.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modelkgyrey6l/prophet_model-20241204052409.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:24:09 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/tfinllxs.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/ka4_ilwe.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=88702', 'data', 'file=/tmp/tmp89kiof8r/tfinllxs.json', 'init=/tmp/tmp89kiof8r/ka4_ilwe.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_model5p2o3yu5/prophet_model-20241204052409.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:24:09 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:24:10 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 05:24:10 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/ip0uk3vm.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/wus04u67.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=64171', 'data', 'file=/tmp/tmp89kiof8r/ip0uk3vm.json', 'init=/tmp/tmp89kiof8r/wus04u67.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modelsortvyes/prophet_model-20241204052410.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:24:10 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/b9fq4ghw.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/a8ggceib.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=78500', 'data', 'file=/tmp/tmp89kiof8r/b9fq4ghw.json', 'init=/tmp/tmp89kiof8r/a8ggceib.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modelevui14ni/prophet_model-20241204052411.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:24:11 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:24:11 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/ivxl7moy.json
# 05:24:11 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/qqznuh0z.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=78072', 'data', 'file=/tmp/tmp89kiof8r/ivxl7moy.json', 'init=/tmp/tmp89kiof8r/qqznuh0z.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modelx30iew5b/prophet_model-20241204052412.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:24:12 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/mkqz9w0m.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/xar3rfpw.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=3717', 'data', 'file=/tmp/tmp89kiof8r/mkqz9w0m.json', 'init=/tmp/tmp89kiof8r/xar3rfpw.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_model_s8xtama/prophet_model-20241204052412.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:24:12 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:24:13 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/6k5wtje_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/gaa9exif.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=33508', 'data', 'file=/tmp/tmp89kiof8r/6k5wtje_.json', 'init=/tmp/tmp89kiof8r/gaa9exif.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_model76_jtgp0/prophet_model-20241204052413.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:24:13 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:24:13 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/hsl54v34.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/h86dubdr.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=5778', 'data', 'file=/tmp/tmp89kiof8r/hsl54v34.json', 'init=/tmp/tmp89kiof8r/h86dubdr.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_model3pinz7ks/prophet_model-20241204052414.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:24:14 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:24:14 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/yp5y_896.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp89kiof8r/x7n2pz6v.json
# DEBUG:cmdstanpy:idx 0
# 05:24:14 - cmdstanpy - INFO - Chain [1] done processing
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=64751', 'data', 'file=/tmp/tmp89kiof8r/yp5y_896.json', 'init=/tmp/tmp89kiof8r/x7n2pz6v.json', 'output', 'file=/tmp/tmp89kiof8r/prophet_modelfp_6aein/prophet_model-20241204052414.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 05:24:14 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 05:24:15 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
# Find the best parameters

# Get the row of the minimum RMSE value in the rmses list
best_params = all_params[np.argmin(rmses)]
print('Best Parameters:', best_params)
# Out:
# Best Parameters: {'changepoint_prior_scale': 0.5, 'seasonality_prior_scale': 10.0, 'holidays_prior_scale': 10.0, 'seasonality_mode': 'multiplicative'}
